# %%
# %matplotlib inline

from __future__ import print_function
from __future__ import division

import pandas as pd
import numpy as np
import math

from matplotlib import pyplot as plt
import seaborn as sn

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

import statsmodels.api as sm

from scipy import stats

from sklearn.ensemble import RandomForestRegressor

# just for the sake of this blog post!
from warnings import filterwarnings
filterwarnings('ignore')
# Out:
# /home/thejan/anaconda2/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ### Reading all dataset - train and test, Concating total_cases

# %%
filepath = 'dataset'
X = pd.read_csv(filepath + '/dengue_features_train.csv')
Y = pd.read_csv(filepath + '/dengue_labels_train.csv')
T = pd.read_csv(filepath + '/dengue_features_test.csv')

# concating total cases to train data frame - beacuse of issue in removing outliers
X = pd.concat([Y['total_cases'], X], axis=1)

# %% [markdown]
# ### Plots HeatMap of a given dataset

# %%
# plot heat map of dataset
def plotHeatMap(dataset):
    f,ax = plt.subplots(figsize=(18, 18))
    sn.heatmap(dataset.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)

# %% [markdown]
# ### Drops features which have correlation (between two features) greater than or equal given threshold

# %%
# remove correlated columns
def correlation(dataset, threshold):
    col_corr = set() # Set of all the names of deleted columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if np.absolute(corr_matrix.iloc[i, j]) >= threshold:
                colname = corr_matrix.columns[i] # getting the name of column
                col_corr.add(colname)
                if colname in dataset.columns:
                    del dataset[colname] # deleting the column from the dataset

# %% [markdown]
# ### Drops columns having more than 10% NaN values

# %%
NaNDic = (X.isnull().sum()*100/X.shape[0])>=10
for i in X.columns.values:
    if(NaNDic[i]):
        X.drop(i,axis=1,inplace=True)
        T.drop(i,axis=1,inplace=True)

# %% [markdown]
# ### Seperating into two cities, Filling null values - interpolation

# %%
# seperate into two cities
X_sj = X[X['city'] == "sj"]
X_iq = X[X['city'] == "iq"]
T_sj = T[T['city'] == "sj"]
T_iq = T[T['city'] == "iq"]
# drop columns
dropping_columns = ['city']
X_sj = X_sj.drop(dropping_columns, axis=1)
X_iq = X_iq.drop(dropping_columns, axis=1)
T_sj = T_sj.drop(dropping_columns, axis=1)
T_iq = T_iq.drop(dropping_columns, axis=1)
# fill NaN values
X_sj.interpolate(inplace=True)
X_iq.interpolate(inplace=True)
T_sj.interpolate(inplace=True)
T_iq.interpolate(inplace=True)

# %% [markdown]
# ### Removing outliers

# %%
# remove outliers
X_sj = X_sj[(np.abs(stats.zscore(X_sj.drop(['year','weekofyear','week_start_date','total_cases'],axis=1))) < 5).all(axis=1)]
X_iq = X_iq[(np.abs(stats.zscore(X_iq.drop(['year','weekofyear','week_start_date','total_cases'],axis=1))) < 5).all(axis=1)]

# %%
# sperating total_cases label again
L_sj = pd.DataFrame(X_sj['total_cases'])
L_iq = pd.DataFrame(X_iq['total_cases'])

# drop total_cases and back X_sj,X_iq in dataset
X_sj = X_sj.drop(['total_cases'],axis=1)
X_iq = X_iq.drop(['total_cases'],axis=1)

# %% [markdown]
# ### Scaling combined dataset of test and train - MinMax Scaler

# %%
# concating test and train
XandT_sj = pd.concat([X_sj, T_sj])
XandT_iq = pd.concat([X_iq, T_iq])

# stores droped columns from XandT_sj, XandT_iq
XandT_sj_rest = pd.DataFrame(XandT_sj[['year','week_start_date']])
XandT_iq_rest = pd.DataFrame(XandT_iq[['year','week_start_date']])

# drop to normalize
XandT_sj.drop(['year','week_start_date'], axis=1, inplace=True)
XandT_iq.drop(['year','week_start_date'], axis=1, inplace=True)

# scaling training set with test set together
XandT_sj[XandT_sj.columns] = MinMaxScaler().fit_transform(XandT_sj)
XandT_iq[XandT_iq.columns] = MinMaxScaler().fit_transform(XandT_iq)

XandT_sj = pd.concat([XandT_sj_rest, XandT_sj], axis=1)
XandT_iq = pd.concat([XandT_iq_rest, XandT_iq], axis=1)

# final scaled X
X_sj = XandT_sj[:926]
X_iq = XandT_iq[:515]

# final scaled T
T_sj = XandT_sj[926:]
T_iq = XandT_iq[515:]

# %% [markdown]
# ### Assigning weights based on correlation

# %%
# correlations
sj_correlations = pd.concat([X_sj, L_sj], axis=1).corr().total_cases.drop('total_cases')
iq_correlations = pd.concat([X_iq, L_iq], axis=1).corr().total_cases.drop('total_cases')


# low results
for i in X_sj.drop(['year','week_start_date'], axis=1).columns.values:
    X_sj[i] = X_sj[i] * np.absolute(sj_correlations[i]) * 100
    X_iq[i] = X_iq[i] * np.absolute(iq_correlations[i]) * 100
    
X_sj
# Out:
#      year week_start_date  weekofyear   ndvi_nw   ndvi_se   ndvi_sw  \
# 0    1990      1990-04-30    9.417087  1.832800  2.420392  2.197934
# 1    1990      1990-05-07    9.971033  2.003298  2.011827  1.996160
# 2    1990      1990-05-14   10.524980  2.139837  1.953504  2.136176
# 3    1990      1990-05-21   11.078926  2.459549  2.749198  2.729188
# 4    1990      1990-05-28   11.632872  2.535523  3.016584  2.833620
# 5    1990      1990-06-04   12.186818  2.148188  3.051805  2.235554
# 6    1990      1990-06-11   12.740765  1.784355  2.494899  2.495656
# 7    1990      1990-06-18   13.294711  1.694339  1.888717  1.791413
# 8    1990      1990-06-25   13.848657  2.021035  1.595805  1.705450
# 9    1990      1990-07-02   14.402604  1.911841  1.992898  2.425410
# 10   1990      1990-07-09   14.956550  1.738017  2.346424  1.972846
# 11   1990      1990-07-16   15.510496  2.312035  3.582052  3.137469
# 12   1990      1990-07-23   16.064443  2.134220  2.741766  2.534730
# 13   1990      1990-07-30   16.618389  2.468787  4.469837  4.055490
# 14   1990      1990-08-06   17.172335  1.658126  2.035416  1.844553
# 15   1990      1990-08-13   17.726281  1.940590  2.516225  2.112471
# 16   1990      1990-08-20   18.280228  2.121361  2.071767  2.149330
# 17   1990      1990-08-27   18.834174  2.839493  3.163282  3.170725
# 18   1990      1990-09-03   19.388120  2.259821  3.385458  2.679565
# 19   1990      1990-09-10   19.942067  3.311079  1.571247  1.930494
# 20   1990      1990-09-17   20.496013  2.181815  3.057621  3.365574
# 21   1990      1990-09-24   21.049959  2.529758  2.431244  2.805144
# 22   1990      1990-10-01   21.603905  2.214259  2.578750  2.412819
# 23   1990      1990-10-08   22.157852  1.672390  2.205326  2.016501
# 25   1990      1990-10-22   23.265744  1.770831  1.632641  1.708446
# 26   1990      1990-10-29   23.819691  2.186249  3.772049  3.276355
# 27   1990      1990-11-05   24.373637  2.178896  2.192455  2.280098
# 28   1990      1990-11-12   24.927583  2.368794  2.215719  2.720071
# 29   1990      1990-11-19   25.481530  2.837719  1.664361  1.721709
# 30   1990      1990-11-26   26.035476  2.332987  2.175006  1.869430
# ..    ...             ...         ...       ...       ...       ...
# 906  2007      2007-10-01   21.603905  1.482676  2.271297  1.651919
# 907  2007      2007-10-08   22.157852  1.834019  1.511631  1.730458
# 908              0.591278              16.007374              15.862062
# 909              0.554912              14.607552              14.302532
# 910              4.631562              10.144591               9.849663
# 911              0.513496              13.446524              13.132885
# 912              1.414218              11.515593              11.696475
# 913              2.470503              11.190340              10.834630
# 914              0.537066               9.082373               8.844177
# 915              0.601042               8.880634               8.351694
# 916              1.053929               8.534796               8.208053
# 917              2.091358               7.867822               7.592449
# 918              0.000000               7.678434               7.571929
# 919              0.000000               6.052171               5.766157
# 920              1.253940               6.352721               6.073959
# 921              0.000000               4.866439               5.047953
# 922              2.734827               5.850432               5.786677
# 923              0.000000               6.002765               5.930318
# 924              0.000000               3.742465               3.344782
# 925              0.000000               5.475774               5.150553
# 926              0.000000               5.673395               5.581476
# 927              0.000000               5.265800               5.622516
# 928              0.000000               5.591053               5.437835
# 929              0.000000               4.775863               4.391308
# 930              0.000000               4.224168               3.796224
# 931              0.915537               2.939626               2.421376
# 932              0.128626               6.175684               6.073959
# 933              0.571075               4.384736               4.165587
# 934              0.000000               4.874674               4.781191
# 935              0.000000               7.880173               7.407768
#
#      reanalysis_dew_point_temp_k        ...          \
# 0                       6.934130        ...
# 1                      10.780070        ...
# 2                      14.490187        ...
# 3                      14.179223        ...
# 4                      15.458820        ...
# 5                      15.533880        ...
# 6                      15.569623        ...
# 7                      17.235244        ...
# 8                      16.852795        ...
# 9                      17.535485        ...
# 10                     16.009261        ...
# 11                     16.741992        ...
# 12                     15.805527        ...
# 13                     16.338096        ...
# 14                     17.238819        ...
# 15                     18.496970        ...
# 16                     17.728497        ...
# 17                     18.450504        ...
# 18                     16.198699        ...
# 19                     18.890142        ...
# 20                     16.985044        ...
# 21                     15.977093        ...
# 22                     17.567654        ...
# 23                     18.228898        ...
# 25                     16.548980        ...
# 26                     17.242393        ...
# 27                     17.317453        ...
# 28                     15.122837        ...
# 29                     14.343641        ...
# 30                     12.931795        ...
# ..                           ...        ...
# 906                    17.514039        ...
# 907                    17.996569        ...
# 908                    16.792032        ...
# 909                    15.591069        ...
# 910                    15.955647        ...
# 911                    15.501712        ...
# 912                    15.001311        ...
# 913                    15.287254        ...
# 914                     9.278866        ...
# 915                    11.623603        ...
# 916                    12.838863        ...
# 917                    13.346413        ...
# 918                    10.722881        ...
# 919                     9.686336        ...
# 920                     9.890071        ...
# 921                     8.449630        ...
# 922                     9.990151        ...
# 923                     8.292361        ...
# 924                     4.739513        ...
# 925                     8.253044        ...
# 926                     8.735574        ...
# 927                     7.155736        ...
# 928                     8.531839        ...
# 929                     6.390837        ...
# 930                     6.412283        ...
# 931                     6.137062        ...
# 932                     8.989349        ...
# 933                     7.731197        ...
# 934                     6.583849        ...
# 935                    11.602157        ...
#
#      reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# 0                           1.571654                              5.608605
# 1                           0.881109                              8.266810
# 2                           1.281880                             11.377536
# 3                           0.682687                             10.238170
# 4                           0.599193                             10.319756
# 5                           1.301035                              9.942181
# 6                           1.895808                             11.342435
# 7                           1.473426                             12.256015
# 8                           1.842273                             11.852826
# 9                           1.394843                             10.865248
# 10                          2.147272                             10.988577
# 11                          2.008770                             11.438252
# 12                          2.088827                             10.507595
# 8             15.262950            9.864936           0.652954
# 9             15.262950           13.021716           0.034040
# 10            10.599271            7.694650           1.971239
# 11            12.931110           12.035222           0.377537
# 12            10.599271            9.864936           1.008829
# 13            16.322877            9.864936           1.163557
# 14            13.991037           10.851430           0.352781
# 15            12.931110            9.864936           1.383271
# 16            13.991037           10.851430           0.167107
# 17            11.659198           13.021716           0.423956
# 18            12.931110           10.851430           0.439429
# 19            15.262950           13.021716           0.801493
# 20            12.931110           12.035222           0.102121
# 21            12.931110           13.021716           0.488942
# 22            13.991037           12.035222           0.362064
# 23            13.991037           13.021716           1.785565
# 25            11.659198            7.694650           2.831529
# 26            13.991037            9.864936           0.194958
# 27            13.991037           12.035222           0.204241
# 28            12.931110            8.681144           1.203787
# 29            10.599271            8.681144           0.297078
# 30             9.327358            5.524364           0.826249
# ..                  ...                 ...                ...
# 906           12.931110            8.681144           2.679895
# 907           13.991037           12.035222           0.448712
# 908           15.262950           13.021716           0.315646
# 909           11.659198           13.021716           0.266133
# 910            8.267431            8.681144           2.760354
# 911           11.659198            9.864936           0.126877
# 912            9.327358            9.864936           2.033131
# 913            9.327358            9.864936           1.250205
# 914            4.663679            8.681144           1.126422
# 915            5.723606            9.864936           1.067626
# 916            4.663679            8.681144           0.934559
# 917            4.663679            7.694650           3.348322
# 918            3.391767            6.510858           0.519887
# 919            5.723606            8.681144           1.717485
# 920            3.391767            6.510858           2.005279
# 921            2.331840            5.524364           0.077364
# 922            2.331840            6.510858           2.571585
# 923            4.663679            4.340572           0.095932
# 924            1.059927            6.510858           1.110950
# 925            3.391767            6.510858           0.198052
# 926            3.391767            7.694650           0.411577
# 927            2.331840            6.510858           0.399199
# 928            5.723606            6.510858           0.402294
# 929            4.663679            8.681144           0.136161
# 930            6.995519            5.524364           0.015473
# 931            6.995519            6.510858           0.055702
# 932            8.267431            8.681144           0.015473
# 933            5.723606            7.694650           0.950032
# 934            5.723606            7.694650           0.346592
# 935           10.599271           10.851430           0.009284
#
# [926 rows x 22 columns]

# %% [markdown]
# ### Training Models

# %%
forest_model_sj = RandomForestRegressor(n_estimators=10000)
forest_model_sj.fit(X_sj.drop(['week_start_date','year'], axis=1), L_sj)

forest_model_iq = RandomForestRegressor(n_estimators=10000)
forest_model_iq.fit(X_iq.drop(['week_start_date','year'], axis=1), L_iq)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10000, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
forest_predict_sj = forest_model_sj.predict(T_sj.drop(['week_start_date','year'], axis=1))
forest_predict_iq = forest_model_iq.predict(T_iq.drop(['week_start_date','year'], axis=1))

# %%
predict_list = list((forest_predict_sj).astype(int)) + list((forest_predict_iq).astype(int))

# %% [markdown]
# ### Write to CSV

# %%
# forest_predict_frame = pd.DataFrame((forest_predict).astype(int))
S = pd.read_csv(filepath + '/submission_format.csv')

S['total_cases'] = predict_list

S

S.to_csv('results/forest_normalized_weighted.csv', index=False)

# %% [raw]
# 1. fill NaN with random forest - feature with correlated columns
# 2. weekofyear drop - month feature
# 3. (correlation_value)^2 * column_value - xxxxxxxxxxxxxxxxxxx
# 4. moving window - *************************
# 5. shift
# 6. weka - **********************
# 7. changing the model
# 8. total_cases correlation high features only
